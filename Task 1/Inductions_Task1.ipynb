# %% [markdown]
# <a href="https://colab.research.google.com/github/Sam-Hack-King/Databyte_inductions/blob/main/Inductions_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Page 4

# Q) Read the Company sales data.
# Code to read csv file into Colaboratory:
"""
from google.colab import files
uploaded = files.upload()

import io
df = pd.read_csv(io.BytesIO(uploaded['company_sales_data1.csv']))

# Dataset is now stored in a Pandas Dataframe
"""

# a) Show the Total profit of all months using a line plot
import csv

import numpy as np
import matplotlib.pyplot as plt

X=[]
Y=[]

with open('company_sales_data1.csv', mode='r') as infile:
    reader = csv.reader(infile)
    for rows in reader :
      temp=rows[0]
      X.append(temp)
      temp=rows[8]
      Y.append(temp)



#print(X)
#print(Y)
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(8, 8))
plt.plot(X,Y)
plt.xlabel('Month')
plt.ylabel('Total_Sales')
plt.show()

# b) Show all product sales data using a multiline plot

import csv
import numpy as np
import matplotlib.pyplot as plt

X=[]
S1=[]
S2=[]
S3=[]
S4=[]
S5=[]
S6=[]
total=[]
total1=0
total2=0
total3=0
total4=0
total5=0
total6=0
with open('company_sales_data1.csv', mode='r') as infile:
    reader = csv.reader(infile)
    for rows in reader :
      temp=rows[0]
      X.append(temp)
      temp=rows[1]
      S1.append(temp)
      temp=rows[2]
      S2.append(temp)
      temp=rows[3]
      S3.append(temp)
      temp=rows[4]
      S4.append(temp)
      temp=rows[5]
      S5.append(temp)
      temp=rows[7]
      S6.append(temp)
fig, ax = plt.subplots()
fig.set_figheight(12)
fig.set_figwidth(12)
line1, = ax.plot(X,S1,label='facecream', color="Red")
line2, = ax.plot(X,S2,label='facewash', color="Cyan")
line3, = ax.plot(X,S3,label='toothpaste', color="Violet")
line4, = ax.plot(X,S4,label='bathingsoap', color="Blue")
line5, = ax.plot(X,S5,label='shampoo', color="Green")
line6, = ax.plot(X,S6,label='moisturizer', color='brown')
plt.style.use('seaborn-darkgrid')
plt.legend(handles=[line1,line2,line3,line4,line5,line6])
plt.show()

for ele in range(0, len(S1)):
    total1 += int(S1[ele])
for ele in range(0, len(S2)):
    total2 += int(S2[ele])
for ele in range(0, len(S3)):
    total3 += int(S3[ele])
for ele in range(0, len(S4)):
    total4 += int(S4[ele])
for ele in range(0, len(S5)):
    total5 += int(S5[ele])
for ele in range(0, len(S6)):
    total6 += int(S6[ele])
# c) Calculate total sales data for last year for each product and show it using a Pie chart
total.insert(0,total1)
total.insert(1,total2)
total.insert(2,total3)
total.insert(3,total4)
total.insert(4,total5)
total.insert(5,total6)
lab = ['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
plt.figure(figsize=(8, 8))
plt.pie(total,labels=lab)
plt.show()

# %%
# Page 5
# a) In your choice of language(Preferably python/R), write a program that prints the numbers ranging from one to 100. 
# But for multiples of three, print "Fizz" instead of the number, and for the multiples of five, print "Buzz." 
# For numbers which are multiples of both three and five, print "FizzBuzz". Upload your code to GitHub repo.
for fizzbuzz in range(1,101):
    if fizzbuzz % 3 == 0 and fizzbuzz % 5 == 0:
        print("fizzbuzz")
        continue
    elif fizzbuzz % 3 == 0:
        print("fizz")
        continue
    elif fizzbuzz % 5 == 0:
        print("buzz")
        continue
    print(fizzbuzz)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %%
#b) Consider the dataset showing the country names and their 2 digit codes. 
# Store the entire dataset from the JSON/CSV format to a Python/R dictionary(key-value pair). 
# Once the dictionary is made, accept the user input as follows: Country code 1, Country code 2. 
# Display the list of country names lying in between the 2 country codes. 
# For example, if the codes given as input are IN and US, the output should display all the country names 
# in full that lie in between India and the United States in alphabetical order excluding these two. 
# Outline the approach and upload your code to the GitHub repo.


# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id':'197_no54kWCOx9Y1Kk2c6QsiYhTsa8lRl'})
downloaded.GetContentFile('data_csv.csv')  
# Dataset is now stored in a Pandas Dataframe

import csv

with open('data_csv.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('data_csv_new.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict = {rows[1]:rows[0] for rows in reader}
print(mydict)
## CSV file is now converted to Python Dictionary (Key- Value Pair)
X=[]
Y=[]

with open('data_csv.csv', mode='r') as infile:
    reader = csv.reader(infile)
    for rows in reader :
      temp=rows[0]
      X.append(temp)
      temp=rows[1]
      Y.append(temp)

#print(X)
#print(Y)


countrycode1 = input("Enter Country Code 1 : ") 
#print(countrycode1) 
countrycode2 = input("Enter Country Code 2 : ") 
#print(countrycode2) 
## Taken User input in form of Country Code 1 and Country Code 2


index1 = Y.index(countrycode1)
index2 = Y.index(countrycode2)

#print(index1)
#print(index2)
Z=[]
for x in range(index1+1,index2): 
    Z.append(X[x])
Z.sort()
for i in range(len(Z)):
  print (Z[i])
## Displayed the list of country names lying in between the 2 country codes. 
## The Displayed list is in ascending order
## Explaination of approach is as follows:
"""
Step 1: CSV file is read and converted to Python Dictionary.
Step 2: The CSV file is divided into 2 lists X and Y. Here X contains 
        Country Names and Y contains Country Codes.
Step 3: 2 Country Codes are taken as input from user.
Step 4: Indexes of the 2 country codes are searched from List X.
Step 5: Country Names between the two indices in the List Y are stored
        in List Z.
Step 6: List Z is sorted.
Step 7: List Z is printed.
"""
# Out:
# {'Code': 'Name', 'EC': 'Ecuador', 'BD': 'Bangladesh', 'MG': 'Madagascar', 'LC': 'Saint Lucia', 'ES': 'Spain', 'MN': 'Mongolia', 'BG': 'Bulgaria', 'BL': 'Saint Barthélemy', 'CY': 'Cyprus', 'NU': 'Niue', 'GL': 'Greenland', 'BZ': 'Belize', 'KP': "Korea, Democratic People's Republic of", 'TM': 'Turkmenistan', 'VN': 'Viet Nam', 'LV': 'Latvia', 'TV': 'Tuvalu', 'PF': 'French Polynesia', 'KH': 'Cambodia', 'BJ': 'Benin', 'RW': 'Rwanda', 'IO': 'British Indian Ocean Territory', 'TL': 'Timor-Leste', 'BS': 'Bahamas', 'PH': 'Philippines', 'MH': 'Marshall Islands', 'SE': 'Sweden', 'GY': 'Guyana', 'MR': 'Mauritania', 'BO': 'Bolivia, Plurinational State of', 'TF': 'French Southern Territories', 'TK': 'Tokelau', 'PE': 'Peru', 'TJ': 'Tajikistan', 'IL': 'Israel', 'SB': 'Solomon Islands', 'ML': 'Mali', 'BE': 'Belgium', 'PW': 'Palau', 'HT': 'Haiti', 'HU': 'Hungary', 'SC': 'Seychelles', 'LI': 'Liechtenstein', 'DK': 'Denmark', 'IR': 'Iran, Islamic Republic of', 'CR': 'Costa Rica', 'DZ': 'Algeria', 'DJ': 'Dj
# ...

# %%
# c) In your choice of language(Preferably python/R), Implement a class with the name MPNeuron. 
# This class implements an MP Neuron.
# Implement the following member functions in your class: 
# (i) Initialise the constructor with the default number of inputs n = 3 and 
#     all inputs being [1,1,1] and the weights being [1,1,1] and threshold as 2.5, 
# (ii) MP_Neuron_Input() - Accepts the number of inputs n, list of n inputs and 
#      the list of n weights with -1 being inhibitory and +1 being excitatory, 
#      and the threshold (theta) also, 
# (iii) MP_Neuron_Evaluate() which outputs the final binary output 0 or 1 if the 
# final value computed by the neuron is greater than the threshold. 
# Test the MP neuron with 3 inputs and choose an appropriate combination of weights 
# and biases to implement a 3 input NAND gate.

class MPNeuron:
  
  def __init__(self,inputs,weights,threshold):
    self.inputs = [1]*3
    self.weights = [1]*3
    self.threshold = 2.5
    
  def MP_Neuron_Input(self,inputs,weights,threshold):
    n = input("Enter number of inputs")
    for i in range(0,n) :
      self.inputs[i] = input("Enter Values of Inputs :").split()
    for i in range(0,n) :
      self.weights[i] = input("Enter Values of Weights :").split()
    threshold = input("Enter Value of Threshold")
